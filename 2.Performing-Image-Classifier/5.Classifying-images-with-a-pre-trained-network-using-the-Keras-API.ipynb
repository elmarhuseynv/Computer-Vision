# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.applications import imagenet_utils
from tensorflow.keras.applications.inception_v3 import *
from tensorflow.keras.preprocessing.image import *

# %%
model = InceptionV3(weights='imagenet')

# %%
image = load_img('dog.jpg', target_size=(299,299))

# %%
image = img_to_array(image)
image = np.expand_dims(image, axis=0)

# %%
image = preprocess_input(image)

# %%
predictions = model.predict(image)
prediction_matrix = (imagenet_utils.decode_predictions(predictions))
# Out:
# 1/1 [==============================] - 4s 4s/step

# %%
for i in range(5):
    _, label, probability = prediction_matrix[0][i]
    print(f'{i + i}. {label}: {probability * 100:.3f}%')
# Out:
# 0. pug: 85.538%
# 2. French_bulldog: 0.585%
# 4. Brabancon_griffon: 0.543%
# 6. Boston_bull: 0.218%
# 8. bull_mastiff: 0.125%

# %%
_, label, _ = prediction_matrix[0][0]
plt.figure()
plt.title(f'Label: {label}.')
original = load_img('dog.jpg')
original = img_to_array(original)
plt.imshow(original / 255.0)
plt.show()
